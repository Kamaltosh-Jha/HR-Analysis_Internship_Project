# %% [markdown]
# # HR Data Analytics

# %% [markdown]
# ### Importing the Required Libraries for EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Getting the CSV File into a Dataframe

# %%
df = pd.read_csv("HR-Employee-Attrition.csv")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.info # summary of df
# Out:
# <bound method DataFrame.info of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum() # null values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
# Dropping Duplicates
df = df.drop_duplicates()

# Removing null values
df = df.dropna()

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
numeric_df = df.select_dtypes(include='number')

# %% [markdown]
# ### Correlation Map

# %%
# Showing a correlation map for all numeric variables
corr_matrix = numeric_df.corr()
plt.figure(figsize=(20, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Map for Numeric Variables')
plt.show()

# %% [markdown]
# ### Visualize the categorical variables

# %%
# Set the pallete using the name of the pallete
sns.set_palette("Paired")
custom_palette = sns.color_palette("Dark2", 20)

# %%
# Overtime
sns.countplot(data=df, x = 'OverTime', 
              hue= 'OverTime', 
              palette=custom_palette[:len(df['OverTime'].unique())], 
              legend = True, saturation=1)
plt.title('OverTime')
plt.show()

# %%
# Marital Status 
sns.countplot(data = df, x = 'MaritalStatus',
              hue= 'MaritalStatus', saturation=1, 
              palette=custom_palette[0:len(df["MaritalStatus"].unique())], 
              legend = True)
plt.title('Marital Status')
plt.show()

# %%
# Job Roles
plt.figure(figsize = (10, 5))
sns.countplot(data = df, y = 'JobRole', 
              palette=custom_palette[0:len(df["JobRole"].unique())], 
              hue = 'JobRole')
plt.title('Job Role')
plt.show()

# %%
# Gender
sns.countplot(data = df, x = 'Gender',
              hue = 'Gender', saturation=1, 
              palette=custom_palette[0:len(df["Gender"].unique())], 
              legend = True)
plt.title("Gender")
plt.show()

# %%
# Education Field
plt.figure(figsize=(10, 5))
sns.countplot(data=df, y = "EducationField", 
              hue = "EducationField", 
              saturation = 1, 
              palette = custom_palette[0:len(df["EducationField"].unique())], 
              legend=False)
plt.title("Education Field")
plt.show()

# %%
# Department
sns.countplot(data=df, x = "Department", 
              hue = "Department", 
              saturation = 1, 
              palette = custom_palette[0:len(df["Department"].unique())], 
              legend=False)
plt.title("Departments of Employees")
plt.show()

# %%
# Business Travel
sns.countplot(data=df, x='BusinessTravel', 
              hue = "BusinessTravel", saturation = 1, 
              palette=custom_palette[:len(df["BusinessTravel"].unique())])
plt.title("Business Travel")
plt.show()

# %%
# Relationship Between Overtime and Age
sns.boxplot(data = df, 
            x = "OverTime", y = "Age", 
            saturation = 1, hue = "OverTime", 
            palette = custom_palette[:len(df["OverTime"].unique())])
plt.title("Relationship Between Overtime and Age")
plt.show()

# %% [markdown]
# ### Plotting numerical variables

# %%
# Total working Years
plt.figure(figsize=(8, 5))
sns.histplot(data = df, x = "TotalWorkingYears", 
             bins = 10, kde = True, color = 'green')
plt.title('Total Working Years')
plt.show()

# %%
# Education Level
sns.histplot(data = df, x = "Education", 
             bins = 10, kde = True, color = 'brown')
plt.title("Education Level")
# Out:
# Text(0.5, 1.0, 'Education Level')

# %%
# Number of Companies Worked
sns.histplot(data = df, x = 'NumCompaniesWorked', 
             bins = 10, 
             kde = True)
plt.title("Number of Companies Worked")
plt.show()

# %%
# Distance from Home
sns.histplot(data = df, x = "DistanceFromHome", bins = 10, 
             kde = True, color = "violet")
plt.title('Distance From Home')
plt.show()

# %% [markdown]
# ### Salary Analysis

# %%
# Monthly Income Distribution
sns.histplot(data = df, x = "MonthlyIncome", bins = 10,
              kde = True, color = "blue")
plt.title("Monthly Income Distribution")
plt.show()

# %%
# Salary by Job Role
plt.figure(figsize = (12, 6))
sns.boxplot(data = df, x = "JobRole", y = "MonthlyIncome", 
            saturation = 1, hue = "JobRole",   
            palette = custom_palette[:len(df["JobRole"].unique())])
plt.title("Salary by Job Role")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Employee Satisfaction and Performance

# %%
# Job Satisfaction Distribution
sns.histplot(data = df, x = "JobSatisfaction", bins = 10, 
             kde = True, color = 'orange')
plt.title("Job Satisfaction Distribution")
plt.show()

# %%
# Performance Rating Distribution
sns.histplot(data = df, x = "PerformanceRating", bins = 10, 
             kde = True, color = "red")
plt.title("Performance Rating Distribution")
plt.show()

# %%
# Employee Tenure
sns.histplot(data = df, x = "YearsAtCompany", bins = 10, 
             kde = True, color = "black")
plt.title("Employee Tenure Distribution") 
plt.show()

# %%
# Age Distribution by Department
plt.figure(figsize = (10, 6))
sns.boxplot(data = df, x = "Department", y = "Age",
            hue = "Department", saturation = 1,  
            palette = custom_palette[:len(df["Department"].unique())])
plt.title("Age Distribution by Department")
plt.show()

# %%
# Attrition by Job Role
plt.figure(figsize = (10, 5))
sns.countplot(data = df, x = "JobRole", 
              hue = "Attrition", saturation = 1, 
              palette = custom_palette[:len(df["Attrition"].unique())])
plt.title("Attrition by Job Roles")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Attrition Prediction Model

# %%
# Assuming 'Attrition' column contains 'Yes' and 'No'
df['Attrition'] = df['Attrition'].map({'Yes': 1, 
                                       'No': 0})
df['BusinessTravel'] = df['BusinessTravel'].map({'Non-Travel': 0, 
                                                'Travel_Rarely': 1, 
                                                'Travel_Frequently': 2})
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df['MaritalStatus'] = df['MaritalStatus'].map({'Married': 0, 
                                               'Single': 1, 
                                               'Divorced': 2})
df['OverTime'] = df['OverTime'].map({'Yes': 1, 
                                     'No': 0})

# Assuming 'Attrition' is the target variable
X = df.drop(['Attrition','Department','EducationField', 'JobRole', 'Over18'], axis=1)# Features
# Assuming 'X' is  feature set with missing values
X.fillna(0, inplace=True)  # Fill missing values with 0 of each column

y = df['Attrition']  # Target variable
y.fillna(0, inplace=True)  # Fill missing values with 0 of each column

# Implement feature selection techniques (e.g., correlation matrix, feature importance)
# get feature importance with Random Forest
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(X, y)
feature_importances = pd.Series(model.feature_importances_, index=X.columns)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Training Model

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize and train the model
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Making predictions
predictions = model.predict(X_test)

# Evaluating model performance
accuracy = accuracy_score(y_test, predictions)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 0.8639455782312925
